# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarthca/Amazon-books-EDA/blob/main/Amazon_books_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as pyo
from plotly.subplots import make_subplots


# Special Visualization
import wordcloud, missingno
from wordcloud import WordCloud # wordcloud
import missingno as msno # check missing value
import networkx as nx

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/bestsellers with categories.csv")
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
#There are 550 number of records in the dataset
df.shape
# Out:
# (550, 7)

# %%
df.sort_values('Reviews',ascending=False).head(10)
# Out:
#                         Name          Author  User Rating  Reviews  Price  \
# 534  Where the Crawdads Sing     Delia Owens          4.8    87841     15
# 382    The Girl on the Train   Paula Hawkins          4.1    79446     18
# 383    The Girl on the Train   Paula Hawkins          4.1    79446      7
# 32                  Becoming  Michelle Obama          4.8    61133     11
# 33                  Becoming  Michelle Obama          4.8    61133     11
# 137                Gone Girl   Gillian Flynn          4.0    57271      9
# 135                Gone Girl   Gillian Flynn          4.0    57271     10
# 136                Gone Girl   Gillian Flynn          4.0    57271     10
# 368   The Fault in Our Stars      John Green          4.7    50482     13
# 367   The Fault in Our Stars      John Green          4.7    50482      7
#
#      Year        Genre
# 534  2019      Fiction
# 382  2015      Fiction
# 383  2016      Fiction
# 32   2018  Non Fiction
# 33   2019  Non Fiction
# 137  2014      Fiction
# 135  2012      Fiction
# 136  2013      Fiction
# 368  2014      Fiction
# 367  2014      Fiction

# %%
#there are 351 number of unique books
len(df.Name.value_counts())
# Out:
# 351

# %%
df[["User Rating", "Price"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'User Rating'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
x=df[df["User Rating"]==4.9]
x.head(10)
# Out:
#                                                   Name                Author  \
# 40            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 41            Brown Bear, Brown Bear, What Do You See?       Bill Martin Jr.
# 81   Dog Man and Cat Kid: From the Creator of Capta...            Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...            Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...            Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...            Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...            Dav Pilkey
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...            Dav Pilkey
# 87   Dog Man: Lord of the Fleas: From the Creator o...            Dav Pilkey
# 146  Goodnight, Goodnight Construction Site (Hardco...  Sherri Duskey Rinker
#
#      User Rating  Reviews  Price  Year    Genre
# 40           4.9    14344      5  2017  Fiction
# 41           4.9    14344      5  2019  Fiction
# 81           4.9     5062      6  2018  Fiction
# 82           4.9     4786      8  2017  Fiction
# 83           4.9     7235      4  2018  Fiction
# 84           4.9     7235      4  2019  Fiction
# 85           4.9    12619      8  2019  Fiction
# 86           4.9     9089      8  2019  Fiction
# 87           4.9     5470      6  2018  Fiction
# 146          4.9     7038      7  2012  Fiction

# %%
y= x.groupby("Name").Reviews.mean().sort_values(ascending= False)
plt.figure(figsize= (10,10))
sns.set_style("whitegrid")
sns.barplot(y.values,y.index)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:ylabel='Name'>
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:88: UserWarning:
#
# Glyph 146 (\x92) missing from current font.
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning:
#
# Glyph 146 (\x92) missing from current font.

# %%
#user ratings and reviews relation
plt.figure(figsize= (12,6))
sns.scatterplot(x="User Rating",y= "Reviews",data= df,hue= "Genre")
# Out:
# <AxesSubplot:xlabel='User Rating', ylabel='Reviews'>

# %%
#user ratings and reviews relation
plt.figure(figsize= (12,6))
sns.scatterplot(x="User Rating",y= "Price",data= df,hue= "Genre")
# Out:
# <AxesSubplot:xlabel='User Rating', ylabel='Price'>

# %%
#reviews over the years
plt.figure(figsize= (12,6))
sns.lineplot(x= "Year",y= "Reviews",data= df,hue="Genre")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Reviews'>

# %%
#prices over the years
plt.figure(figsize= (12,6))
sns.lineplot(x= "Year",y= "Price",data= df,hue="Genre")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Price'>

# %%
df['Author'].value_counts()
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: Author, Length: 248, dtype: int64

# %%
#BESTSELLING BOOKS' AUTHORS:
temp_df1 = df.groupby('Author').count().reset_index().sort_values('Name',ascending=False).head(10)

# %%
top = go.Bar(
                x = temp_df1['Author'],
                y = temp_df1['Name'],
                marker = dict(color = 'cyan',
                             line=dict(color='rgb(0,0,0)',width=1.5)))
layout = go.Layout(template= "plotly_white",title = 'Top 10 Best-Selling Authors ' , 
                   xaxis = dict(title = 'Author',tickangle=45), yaxis = dict(title = 'count'))
fig = go.Figure(data = [top], layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2495499e-ddc2-4117-9e32-b6704132273a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2495499e-ddc2-4117-9e32-b6704132273a")) {                    Plotly.newPlot(                        "2495499e-ddc2-4117-9e32-b6704132273a",                        [{"marker":{"color":"cyan","line":{"color":"rgb(0,0,0)","width":1.5}},"x":["Jeff Kinney","Gary Chapman","Suzanne Collins","Rick Riordan","American Psychological Association","Gallup","Dr. Seuss","Rob Elliott","Eric Carle","Bill O'Reilly"],"y":[12,11,11,11,10,9,9,8,7,7],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colo ...

# %%
df1 = df.groupby('Author').mean().sort_values('Reviews',ascending=False).reset_index().head(10)

fig = px.scatter(df1, x='User Rating', y='Reviews', color='Author')

fig.update_traces(marker=dict(size=10,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="61d7bca4-6a43-4707-84be-cc75ee7e8425" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61d7bca4-6a43-4707-84be-cc75ee7e8425")) {                    Plotly.newPlot(                        "61d7bca4-6a43-4707-84be-cc75ee7e8425",                        [{"hovertemplate":"Author=Delia Owens<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Delia Owens","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Delia Owens","orientation":"v","showlegend":true,"x":[4.8],"xaxis":"x","y":[87841.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Paula Hawkins<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Paula Hawkins","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Paula Hawkins","orientation":"v","showlegend":true,"x":[4.1],"xaxis":"x","y":[79446.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Michelle Obama<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Michelle Obama","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Michelle Obama","orientation":"v","showlegend":true,"x":[4.8],"xaxis":"x","y":[61133.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Gillian Flynn<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Gillian Flynn","marker":{"color":"#ab63fa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Gillian Flynn","orientation":"v","showlegend":true,"x":[4.0],"xaxis":"x","y":[57271.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Kristin Hannah<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Kristin Hannah","marker":{"color":"#FFA15A","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Kristin Hannah","orientation":"v","showlegend":true,"x":[4.8],"xaxis":"x","y":[49288.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=John Green<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"John Green","marker":{"color":"#19d3f3","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"John Green","orientation":"v","showlegend":true,"x":[4.66],"xaxis":"x","y":[42083.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Andy Weir<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Andy Weir","marker":{"color":"#FF6692","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Andy Weir","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","y":[39459.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Anthony Doerr<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Anthony Doerr","marker":{"color":"#B6E880","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Anthony Doerr","orientation":"v","showlegend":true,"x":[4.6],"xaxis":"x","y":[36348.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Paulo Coelho<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Paulo Coelho","marker":{"color":"#FF97FF","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":10},"mode":"markers","name":"Paulo Coelho","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","y":[35799.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Author=Donna Tartt<br>User Rating=%{x}<br>Reviews=%{y}<extra></extra>","legendgroup":"Donna Tartt","marker":{"color":"#FECB52","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"si ...

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
Fiction = df[df["Genre"]=='Fiction']
Fiction.head(10)
# Out:
#                                                  Name               Author  \
# 1                                   11/22/63: A Novel         Stephen King
# 3                              1984 (Signet Classics)        George Orwell
# 5       A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6   A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                      A Gentleman in Moscow: A Novel          Amor Towles
# 9                           A Man Called Ove: A Novel      Fredrik Backman
# 10                          A Man Called Ove: A Novel      Fredrik Backman
# 13                   A Wrinkle in Time (Time Quintet)    Madeleine L'Engle
# 20                        All the Light We Cannot See        Anthony Doerr
# 21                        All the Light We Cannot See        Anthony Doerr
#
#     User Rating  Reviews  Price  Year    Genre
# 1           4.6     2052     22  2011  Fiction
# 3           4.7    21424      6  2017  Fiction
# 5           4.4    12643     11  2011  Fiction
# 6           4.7    19735     30  2014  Fiction
# 7           4.7    19699     15  2017  Fiction
# 9           4.6    23848      8  2016  Fiction
# 10          4.6    23848      8  2017  Fiction
# 13          4.5     5153      5  2018  Fiction
# 20          4.6    36348     14  2014  Fiction
# 21          4.6    36348     14  2015  Fiction

# %%
Non_Fiction = df[df["Genre"]=='Non Fiction']
Non_Fiction.head(10)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 2             12 Rules for Life: An Antidote to Chaos
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 17     Adult Coloring Book: Stress Relieving Patterns
#
#                          Author  User Rating  Reviews  Price  Year  \
# 0                      JJ Smith          4.7    17350      8  2016
# 2            Jordan B. Peterson          4.7    18979     15  2018
# 4      National Geographic Kids          4.8     7665     12  2019
# 8                   James Comey          4.7     5983      3  2018
# 11             Larry Schweikart          4.6      460      2  2010
# 12                Jaycee Dugard          4.6     4149     32  2011
# 14                 Steve Harvey          4.6     5013     17  2009
# 15  Adult Coloring Book Designs          4.5     2313      4  2016
# 16           Blue Star Coloring          4.6     2925      6  2015
# 17           Blue Star Coloring          4.4     2951      6  2015
#
#           Genre
# 0   Non Fiction
# 2   Non Fiction
# 4   Non Fiction
# 8   Non Fiction
# 11  Non Fiction
# 12  Non Fiction
# 14  Non Fiction
# 15  Non Fiction
# 16  Non Fiction
# 17  Non Fiction

# %%
from wordcloud import WordCloud

text=' '.join(Fiction['Author'])

plt.rcParams['figure.figsize']=(16,16)
wordcloud=WordCloud(background_color='black', colormap='vlag', 
                    width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud

text=' '.join(Non_Fiction['Author'])

plt.rcParams['figure.figsize']=(15,15)
wordcloud=WordCloud(background_color='black', colormap='vlag', 
                    width=1200, height=1200, max_words=121).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
